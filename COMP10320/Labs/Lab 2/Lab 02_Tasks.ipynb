# %% [markdown]
# # Lab 1 Tasks
#
# The tasks in this lab are based on Lecture 3 and on materials in the following Notebooks, which are available on BrightSpace: <br>
#      03 - Data Structures.ipynb <br>
#      04 - Flow Control.ipynb
#
# Tasks 5 and 6 ask you to create a function. For details of the notation for a functio,n please see slide 10 in Lecture 3. <br><br>

# %% [markdown]
# The code below creates two Python lists -- one list with English words, and a corresponding list with French words.

# %%
english = ["hello", "cat", "dog", "yes", "tomorrow", "yesterday", "fish",
          "difficult", "easy", "bad", "no", "tuesday", "january", "world"]

# %%
french = ["bonjour", "chat", "chien", "oui", "demain", "hier", "poisson",
          "difficile", "facile", "mauvais", "non", "mardi", "janvier", "monde"]

# %% [markdown]
# ## Task 1
#
# Confirm that both lists contain an equal number of values.

# %%
english = ["hello", "cat", "dog", "yes", "tomorrow", "yesterday", "fish",
          "difficult", "easy", "bad", "no", "tuesday", "january", "world"]

french = ["bonjour", "chat", "chien", "oui", "demain", "hier", "poisson",
          "difficile", "facile", "mauvais", "non", "mardi", "janvier", "monde"]

if len(english) == len(french):
    print("Yay")
# Out:
# Yay

# %% [markdown]
# ## Task 2
#
# Create a Python dictionary, which maps English words to French words, using the two lists above.

# %%
english = ["hello", "cat", "dog", "yes", "tomorrow", "yesterday", "fish",
          "difficult", "easy", "bad", "no", "tuesday", "january", "world"]

french = ["bonjour", "chat", "chien", "oui", "demain", "hier", "poisson",
          "difficile", "facile", "mauvais", "non", "mardi", "janvier", "monde"]

translator = {}
for i in range( len(english) ):
    translator[ english[i] ] = french[i]

translator["hello"]
# Out:
# 'bonjour'

# %% [markdown]
# ## Task 3
#
# Remove all key-value pairs from the dictionary above, where the keys (i.e. the English words) contain less than 4 characters. <br>
#
# Note: you can test for the lenght of a word by using the function len(word).<br>

# %%
english = ["hello", "cat", "dog", "yes", "tomorrow", "yesterday", "fish",
          "difficult", "easy", "bad", "no", "tuesday", "january", "world"]

french = ["bonjour", "chat", "chien", "oui", "demain", "hier", "poisson",
          "difficile", "facile", "mauvais", "non", "mardi", "janvier", "monde"]

translator = {}
for i in range( len(english) ):
    if len(english[i]) >= 4:
        translator[ english[i] ] = french[i]

translator
# Out:
# {'hello': 'bonjour',
#  'tomorrow': 'demain',
#  'yesterday': 'hier',
#  'fish': 'poisson',
#  'difficult': 'difficile',
#  'easy': 'facile',
#  'tuesday': 'mardi',
#  'january': 'janvier',
#  'world': 'monde'}

# %% [markdown]
# ## Task 4
#
# For the remaining words, print an alphabetically-ordered list of the English words and their corresponding French translations.

# %%
english = ["hello", "cat", "dog", "yes", "tomorrow", "yesterday", "fish",
          "difficult", "easy", "bad", "no", "tuesday", "january", "world"]

french = ["bonjour", "chat", "chien", "oui", "demain", "hier", "poisson",
          "difficile", "facile", "mauvais", "non", "mardi", "janvier", "monde"]

english = sorted(english)
french = sorted(french)

translator = {}
for i in range( len(english) ):
    if len(english[i]) >= 4:
        translator[ english[i] ] = french[i]

translator
# Out:
# {'difficult': 'chien',
#  'easy': 'difficile',
#  'fish': 'facile',
#  'hello': 'hier',
#  'january': 'janvier',
#  'tomorrow': 'mauvais',
#  'tuesday': 'monde',
#  'world': 'non',
#  'yesterday': 'poisson'}

# %% [markdown]
# ## Task 5
#
# Write a new function named *translate()* which accepts 3 arguments: a translation dictionary, a word to translate, and a default word. If the word is in the dictionary, the function should return the translated word. Otherwise, it should return the default word.

# %%
english = ["hello", "cat", "dog", "yes", "tomorrow", "yesterday", "fish",
          "difficult", "easy", "bad", "no", "tuesday", "january", "world"]

french = ["bonjour", "chat", "chien", "oui", "demain", "hier", "poisson",
          "difficile", "facile", "mauvais", "non", "mardi", "janvier", "monde"]

translator = {}
for i in range(len(english)):
    translator[english[i]] = french[i]


def translate(dictionary, word, default = "Word not in dictionary"):
    if word in dictionary:
        return dictionary[word]
    else:
        return default

word = input("Enter a word")
result = translate(translator, word)
print(f"The result is {result}")
# Out:
# The result is Word not in dictionary

# %% [markdown]
# ## Task 6
#
# Write a new function named *reverse_translate()* which accepts 2 arguments: a translation dictionary and a word in the target translation language. If the translation is found, it returns the original word; otherwise, it returns a default message indicating that the translation is not available

# %%
english = ["hello", "cat", "dog", "yes", "tomorrow", "yesterday", "fish",
          "difficult", "easy", "bad", "no", "tuesday", "january", "world"]

french = ["bonjour", "chat", "chien", "oui", "demain", "hier", "poisson",
          "difficile", "facile", "mauvais", "non", "mardi", "janvier", "monde"]

translator = {}
for i in range(len(english)):
    translator[english[i]] = french[i]

def reverse_translate(dictionary, word):
    for original_word, translated_word in dictionary.items():
        if translated_word == word:
            return original_word
    return "Word not in dictionary"

word = input("Enter a word")
result = reverse_translate(translator, word)
print(f"The result is {result}")
# Out:
# The result is yes
